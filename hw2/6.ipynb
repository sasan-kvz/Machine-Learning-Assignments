# %%
import numpy as np
import math

# %%
def ring():
    circle = False
    while circle == False:        
        r = np.array([np.random.uniform(-9, 9), np.random.uniform(-9., 9.)])

        if (r[0]**2+r[1]**2 < 81) and (r[0]**2+r[1]**2 > 16):
            circle = True

        else :
            circle = False

    return r[0], r[1]

x1 = np.zeros(200)
y1 = np.zeros(200)
for i in range(200):
    x1[i], y1[i] = ring()
x1 = x1 + 1.5


def ring():
    circle = False
    while circle == False:        
        r = np.array([np.random.uniform(-6, 6), np.random.uniform(-6., 6.)])

        if (r[0]**2+r[1]**2 < 36) and (r[0]**2+r[1]**2 >0):
            circle = True

        else :
            circle = False

    return r[0], r[1]

x2 = np.zeros(200)
y2 = np.zeros(200)
for i in range(200):
    x2[i], y2[i] = ring()
x2 = x2 + 1.5

plt.figure(figsize =(8,6))
plt.scatter(x1,y1)
plt.scatter(x2,y2)

# %%
x3 = np.random.normal(1, 1, 100)
y3 = np.random.normal(0, 1, 100)

def ring():
    circle = False
    while circle == False:        
        r = np.array([np.random.uniform(-6, 6), np.random.uniform(-6., 6.)])

        if (r[0]**2+r[1]**2 < 36) and (r[0]**2+r[1]**2 >4):
            circle = True

        else :
            circle = False

    return r[0], r[1]

x4 = np.zeros(200)
y4 = np.zeros(200)
for i in range(200):
    x4[i], y4[i] = ring2()
x4 = x4 + 1.5

plt.figure(figsize =(8,6))
plt.scatter(x3,y3)
plt.scatter(x4,y4)
